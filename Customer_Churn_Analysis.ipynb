# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = {
    "Customer_ID":[101,102,103,104,105,106,107,108,109,110,
                   111,112,113,114,115,116,117,118,119,120],

    "Age":[22,25,30,35,40,28,50,45,33,27,
           38,29,41,36,26,48,32,37,44,31],

    "Subscription_Months":[2,5,24,18,36,3,48,30,12,4,
                           20,8,40,16,6,50,14,22,28,10],

    "Login_Frequency":[2,4,25,20,30,1,28,22,12,3,
                       18,7,26,15,5,32,14,19,24,8],

    "Support_Tickets":[8,5,1,2,0,10,0,1,3,7,
                       2,4,1,3,6,0,2,1,1,4],

    "Monthly_Spend":[100,150,700,650,900,80,950,750,500,120,
                     600,300,850,550,250,1000,450,620,780,350],

    "Churn":[1,1,0,0,0,1,0,0,0,1,
             0,1,0,0,1,0,0,0,0,1]
}

df = pd.DataFrame(data)

df.head()
# Out:
#    Customer_ID  Age  Subscription_Months  Login_Frequency  Support_Tickets  \
# 0          101   22                    2                2                8
# 1          102   25                    5                4                5
# 2          103   30                   24               25                1
# 3          104   35                   18               20                2
# 4          105   40                   36               30                0
#
#    Monthly_Spend  Churn
# 0            100      1
# 1            150      1
# 2            700      0
# 3            650      0
# 4            900      0

# %%
print(df.shape)

df.info()

df.describe()
# Out:
# (20, 7)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Customer_ID          20 non-null     int64
#  1   Age                  20 non-null     int64
#  2   Subscription_Months  20 non-null     int64
#  3   Login_Frequency      20 non-null     int64
#  4   Support_Tickets      20 non-null     int64
#  5   Monthly_Spend        20 non-null     int64
#  6   Churn                20 non-null     int64
# dtypes: int64(7)
# memory usage: 1.2 KB
#        Customer_ID        Age  Subscription_Months  Login_Frequency  \
# count     20.00000  20.000000            20.000000        20.000000
# mean     110.50000  34.850000            19.800000        15.750000
# std        5.91608   7.955634            14.827428        10.067535
# min      101.00000  22.000000             2.000000         1.000000
# 25%      105.75000  28.750000             7.500000         6.500000
# 50%      110.50000  34.000000            17.000000        16.500000
# 75%      115.25000  40.250000            28.500000        24.250000
# max      120.00000  50.000000            50.000000        32.000000
#
#        Support_Tickets  Monthly_Spend     Churn
# count        20.000000      20.000000  20.00000
# mean          3.050000     532.500000   0.35000
# std           2.855742     296.911736   0.48936
# min           0.000000      80.000000   0.00000
# 25%           1.000000     287.500000   0.00000
# 50%           2.000000     575.000000   0.00000
# 75%           4.250000     757.500000   1.00000
# max          10.000000    1000.000000   1.00000

# %%
churn_count = df["Churn"].value_counts()

print(churn_count)

churn_count.plot(kind="bar")

plt.title("Customer Churn Distribution")
plt.ylabel("Count")
plt.show()
# Out:
# Churn
# 0    13
# 1     7
# Name: count, dtype: int64

# %%
df.groupby("Churn").mean(numeric_only=True)
# Out:
#        Customer_ID        Age  Subscription_Months  Login_Frequency  \
# Churn
# 0       111.076923  39.153846            27.538462        21.923077
# 1       109.428571  26.857143             5.428571         4.285714
#
#        Support_Tickets  Monthly_Spend
# Churn
# 0             1.307692     715.384615
# 1             6.285714     192.857143

# %%
df.groupby("Churn")["Login_Frequency"].mean()
# Out:
# Churn
# 0    21.923077
# 1     4.285714
# Name: Login_Frequency, dtype: float64

# %%
df.groupby("Churn")["Login_Frequency"].mean().plot(kind="bar")

plt.title("Average Login Frequency")
plt.ylabel("Logins")
plt.show()

# %%
df.groupby("Churn")["Subscription_Months"].mean()
# Out:
# Churn
# 0    27.538462
# 1     5.428571
# Name: Subscription_Months, dtype: float64

# %%
df.groupby("Churn")["Subscription_Months"].mean().plot(kind="bar")

plt.title("Subscription Duration")
plt.ylabel("Months")
plt.show()

# %%
df.groupby("Churn")["Support_Tickets"].mean()
# Out:
# Churn
# 0    1.307692
# 1    6.285714
# Name: Support_Tickets, dtype: float64

# %%
df.groupby("Churn")["Support_Tickets"].mean().plot(kind="bar")

plt.title("Support Tickets vs Churn")
plt.ylabel("Tickets")
plt.show()

# %%
df.groupby("Churn")["Monthly_Spend"].mean()
# Out:
# Churn
# 0    715.384615
# 1    192.857143
# Name: Monthly_Spend, dtype: float64

# %%
df.groupby("Churn")["Monthly_Spend"].mean().plot(kind="bar")

plt.title("Monthly Spending")
plt.ylabel("Amount")
plt.show()

# %%
correlation = df.corr(numeric_only=True)

print(correlation["Churn"])
# Out:
# Customer_ID           -0.136347
# Age                   -0.756385
# Subscription_Months   -0.729709
# Login_Frequency       -0.857313
# Support_Tickets        0.853035
# Monthly_Spend         -0.861213
# Churn                  1.000000
# Name: Churn, dtype: float64

# %%
# Findings

# 1. Customers with low login frequency are more likely to churn.

# 2. Customers with shorter subscription durations show higher churn rates.

# 3. Customers raising more support tickets tend to churn more often.

# 4. Customers with lower monthly spending have a higher probability of leaving.

# 5. Long-term and highly engaged customers are less likely to churn.

# %%
# Recommendations

# 1. Increase engagement through notifications and personalized content.

# 2. Offer loyalty rewards for long-term subscribers.

# 3. Improve customer support response times.

# 4. Provide special discounts to inactive customers.

# 5. Identify low-engagement users early and launch retention campaigns.

# %%
df.to_csv("customer_churn_analysis.csv", index=False)

print("Analysis completed successfully.")
# Out:
# Analysis completed successfully.
